# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("netflix.csv")

df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#Analisi type Movie dan TV Show

type_counts = df['type'].value_counts()

plt.bar(type_counts.index, type_counts.values, color = ['skyblue', 'red'])
plt.title('Distribusi Tipe konten')
plt.xlabel('Tipe')
plt.ylabel('Jumlah')
plt.grid(axis='y')
plt.show()

# %%
#Analisis Genre terpopuler

genre_series = df['listed_in'].dropna().str.split('.')
all_genres = genre_series.explode()
genre_counts = all_genres.value_counts().head(10)

plt.barh(genre_counts.index[::-1], genre_counts.values[::-1], color = 'pink')
plt.title('10 Genre Terpopuler')
plt.xlabel('Jumlah')
plt.ylabel('Genre')
plt.grid(axis='x')
plt.show()

# %%
#Analisis Tren Konten pertahun 

year_counts = df['release_year'].value_counts().sort_index()

plt.plot(year_counts.index, year_counts.values, color='darkgreen', marker= 'o')
plt.title('Jumlah Konten Dirilis PerTahun')
plt.xlabel('Tahun')
plt.ylabel('Jumlah')
plt.grid(True)
plt.show()

# %%
#Analisis Negara Asal Terbanyak

country_series = df['country'].dropna().str.split('.')
all_countries = country_series.explode()
country_counts = all_countries.value_counts().head(10)

plt.barh(country_counts.index[::-1], country_counts.values[::-1], color = 'orange')
plt.title('10 Negara Asal Konten Terbanyak')
plt.xlabel('Jumlah')
plt.ylabel('Negara')
plt.grid(axis='x')
plt.show()

# %%
#Analisis Durasi Film

movie_df = df[df['type'] == 'Movie'].copy()
movie_df['duration_minutes'] = movie_df['duration'].str.extract('(\d+)').astype(float)

plt.hist(movie_df['duration_minutes'].dropna(), bins=30, color = 'yellow', edgecolor='black')
plt.title('Distribusi Durasi Film(Menit)')
plt.xlabel('Durasi')
plt.ylabel('Jumlah Film')
plt.grid(True)
plt.show()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\HP\AppData\Local\Temp\ipykernel_8400\1816173262.py:4: SyntaxWarning: invalid escape sequence '\d'
#   movie_df['duration_minutes'] = movie_df['duration'].str.extract('(\d+)').astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
